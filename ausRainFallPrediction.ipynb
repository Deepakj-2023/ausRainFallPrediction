# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
 df = pd.read_csv("C://Users//Deepak//Documents//weatherAUS.csv")

# %%
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          4.8       8.4
# 1  2008-12-02   Albury      7.4     25.1       0.0          4.8       8.4
# 2  2008-12-03   Albury     12.9     25.7       0.0          4.8       8.4
# 3  2008-12-04   Albury      9.2     28.0       0.0          4.8       8.4
# 4  2008-12-05   Albury     17.5     32.3       1.0          4.8       8.4
# 5  2008-12-06   Albury     14.6     29.7       0.2          4.8       8.4
# 6  2008-12-07   Albury     14.3     25.0       0.0          4.8       8.4
# 7  2008-12-08   Albury      7.7     26.7       0.0          4.8       8.4
# 8  2008-12-09   Albury      9.7     31.9       0.0          4.8       8.4
# 9  2008-12-10   Albury     13.1     30.1       1.4          4.8       8.4
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        145460 non-null  float64
#  3   MaxTemp        145460 non-null  float64
#  4   Rainfall       145460 non-null  float64
#  5   Evaporation    145460 non-null  float64
#  6   Sunshine       145460 non-null  float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  145460 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   145460 non-null  float64
#  12  WindSpeed3pm   145460 non-null  float64
#  13  Humidity9am    145460 non-null  float64
#  14  Humidity3pm    145460 non-null  float64
#  15  Pressure9am    145460 non-null  float64
# ...

# %%
#missing the value 
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Date             0.000000
# Location         0.000000
# MinTemp          0.000000
# MaxTemp          0.000000
# Rainfall         0.000000
# Evaporation      0.000000
# Sunshine         0.000000
# WindGustDir      7.098859
# WindGustSpeed    0.000000
# WindDir9am       7.263853
# WindDir3pm       2.906641
# WindSpeed9am     0.000000
# WindSpeed3pm     0.000000
# Humidity9am      0.000000
# Humidity3pm      0.000000
# Pressure9am      0.000000
# Pressure3pm      0.000000
# Cloud9am         0.000000
# Cloud3pm         0.000000
# Temp9am          0.000000
# Temp3pm          0.000000
# RainToday        2.241853
# RainTomorrow     2.245978
# dtype: float64

# %%
# finding the duplicate value
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# the grabage value is object dattype  2-3-2024 '-' is the garbage value

# %%
for i in df.select_dtypes(include ='object').columns:
    print(df[i].value_counts())
    print("***"*10)
# Out:
# Date
# 2013-11-12    49
# 2014-09-01    49
# 2014-08-23    49
# 2014-08-24    49
# 2014-08-25    49
#               ..
# 2007-11-29     1
# 2007-11-28     1
# 2007-11-27     1
# 2007-11-26     1
# 2008-01-31     1
# Name: count, Length: 3436, dtype: int64
# ******************************
# Location
# Canberra            3436
# Sydney              3344
# Darwin              3193
# Melbourne           3193
# Brisbane            3193
# Adelaide            3193
# Perth               3193
# Hobart              3193
# Albany              3040
# MountGambier        3040
# Ballarat            3040
# Townsville          3040
# GoldCoast           3040
# Cairns              3040
# Launceston          3040
# AliceSprings        3040
# Bendigo             3040
# Albury              3040
# MountGinini         3040
# Wollongong          3040
# Newcastle           3039
# Tuggeranong         3039
# Penrith             3039
# Woomera             3009
# Nuriootpa           3009
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean       12.194034      23.221348       2.360918       5.179779
# std         6.365750       7.088124       8.382488       3.178819
# min        -8.500000      -4.800000       0.000000       0.000000
# 25%         7.700000      18.000000       0.000000       4.000000
# 50%        12.100000      22.700000       0.000000       4.800000
# 75%        16.800000      28.200000       1.000000       5.200000
# max        33.900000      48.100000     371.000000     145.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean        7.989889      40.035230      14.043426      18.662657
# std         2.757790      13.118253       8.861059       8.716581
# min         0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.describe(include ="object")
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count       145460    145460      135134     134894     141232    142199
# unique        3436        49          16         16         16         2
# top     2013-11-12  Canberra           W          N         SE        No
# freq            49      3436        9915      11758      10838    110319
#
#        RainTomorrow
# count        142193
# unique            2
# top              No
# freq         110316

# %%
# the histrogram will be easy to understand the distribution
import warnings
warnings.filterwarnings("ignore")
for i in df.select_dtypes(include="number").columns:
     sns.histplot(data = df,x=i)
     plt.show()

# %%
# boxplot it will be used find the outlier 
import warnings
warnings.filterwarnings("ignore")
for i in df.select_dtypes(include="number").columns:
     sns.boxplot(data = df,x=i)
     plt.show()

# %%
#scatter plot 
df.select_dtypes(include ="number").columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm'],
#       dtype='object')

# %%
for i in ['MinTemp', 'MaxTemp',  'Evaporation', 'Sunshine',
       'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
       'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
       'Temp9am', 'Temp3pm']:
     sns.scatterplot(data =df,x=i,y='Rainfall')
     plt.show()

# %%
#correlation 
s =df.select_dtypes(include='number').corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(s,annot=True)
# Out:
# <Axes: >

# %%
# missing value treatments
# mean,medium ,mode or KNNInputer
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
# filling the null value  to the mediem value
for i in ["Evaporation","Sunshine","Cloud9am","Cloud3pm"] :
        df[i].fillna(df[i].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
from sklearn.impute import KNNImputer
impute = KNNImputer()

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
for i in df.select_dtypes(include="number").columns:
     df[i] =impute.fit_transform(df[[i]])

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall             0
# Evaporation          0
# Sunshine             0
# WindGustDir      10326
# WindGustSpeed        0
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am         0
# WindSpeed3pm         0
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am             0
# Cloud3pm             0
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
# outliers treatments
# only for the continues variable

# %%
def wisker(col):
    q1,q3 =np.percentile(col,[25,75])
    iqr = q3-q1
    uw = q3+1.5*iqr
    lw =q1-1.5*iqr
    return lw,uw

# %%
wisker(df['Humidity3pm'])
# Out:
# (-5.0, 107.0)

# %%
for i in ['Humidity3pm','Pressure9am','Pressure3pm']:
    lw,uw = wisker(df[i])
    df[i] = np.where(df[i]<lw,lw,df[i])
    df[i] = np.where(df[i]>uw,uw,df[i])

# %%
for i in ['Humidity3pm','Pressure9am','Pressure3pm']:
     sns.boxplot(df[i])
     plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
# duplicates values and the garpage values

# %%
df.drop_duplicates()
# Out:
#               Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4  22.900000       0.6          4.8
# 1       2008-12-02   Albury      7.4  25.100000       0.0          4.8
# 2       2008-12-03   Albury     12.9  25.700000       0.0          4.8
# 3       2008-12-04   Albury      9.2  28.000000       0.0          4.8
# 4       2008-12-05   Albury     17.5  32.300000       1.0          4.8
# ...            ...      ...      ...        ...       ...          ...
# 145455  2017-06-21    Uluru      2.8  23.400000       0.0          4.8
# 145456  2017-06-22    Uluru      3.6  25.300000       0.0          4.8
# 145457  2017-06-23    Uluru      5.4  26.900000       0.0          4.8
# 145458  2017-06-24    Uluru      7.8  27.000000       0.0          4.8
# 145459  2017-06-25    Uluru     14.9  23.221348       0.0          4.8
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
# encode the data 
# the data  in numerical value 
# object to convert the numerical value
# encodeing the dummmies value
dummy =pd.get_dummies(data =df,columns =['WindDir9am','WindDir3pm'],drop_first =True)

# %%
dummy
# Out:
#               Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4  22.900000       0.6          4.8
# 1       2008-12-02   Albury      7.4  25.100000       0.0          4.8
# 2       2008-12-03   Albury     12.9  25.700000       0.0          4.8
# 3       2008-12-04   Albury      9.2  28.000000       0.0          4.8
# 4       2008-12-05   Albury     17.5  32.300000       1.0          4.8
# ...            ...      ...      ...        ...       ...          ...
# 145455  2017-06-21    Uluru      2.8  23.400000       0.0          4.8
# 145456  2017-06-22    Uluru      3.6  25.300000       0.0          4.8
# 145457  2017-06-23    Uluru      5.4  26.900000       0.0          4.8
# 145458  2017-06-24    Uluru      7.8  27.000000       0.0          4.8
# 145459  2017-06-25    Uluru     14.9  23.221348       0.0          4.8
#
#         Sunshine WindGustDir  WindGustSpeed  WindSpeed9am  ...  \
# ...
